# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import (
    roc_curve,
    auc,
    ConfusionMatrixDisplay,
    confusion_matrix,
)

from sklearn.calibration import calibration_curve

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(values_format="d")
plt.title("Genesis Quant Confusion Matrix (Counts)")
plt.tight_layout()
plt.show()

# Optionally, normalized confusion matrix (per-row / per-class)
cm_norm = confusion_matrix(y_test, y_pred, normalize="true")

disp_norm = ConfusionMatrixDisplay(confusion_matrix=cm_norm)
disp_norm.plot(values_format=".2f")
plt.title("Genesis Quant Confusion Matrix (Row-Normalized)")
plt.tight_layout()
plt.savefig("/output/Genesis Quant Confusion Matrix (Row-Normalized).pdf")
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 1157

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(values_format="d")
plt.title("Omni CST Confusion Matrix (Counts)")
plt.tight_layout()
plt.show()

# Optionally, normalized confusion matrix (per-row / per-class)
cm_norm = confusion_matrix(y_test, y_pred, normalize="true")
disp_norm = ConfusionMatrixDisplay(confusion_matrix=cm_norm)
disp_norm.plot(values_format=".2f")
plt.title("Omni CST Confusion Matrix (Row-Normalized)")
plt.tight_layout()
plt.savefig("/output/Omni CST Confusion Matrix (Row-Normalized).pdf")
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(values_format="d")
plt.title("Omni Quant derived Confusion Matrix (Counts)")
plt.tight_layout()
plt.show()

# Optionally, normalized confusion matrix (per-row / per-class)
cm_norm = confusion_matrix(y_test, y_pred, normalize="true")
disp_norm = ConfusionMatrixDisplay(confusion_matrix=cm_norm)
disp_norm.plot(values_format=".2f")
plt.title("Omni Quant derived Confusion Matrix (Row-Normalized)")
plt.tight_layout()
plt.savefig("/output/Omni Quant derived Confusion Matrix (Row-Normalized).pdf")
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
n_classes = 6

plt.figure()
for c in range(n_classes):
    # Binary ground truth for class c vs rest
    y_true_c = (y_test == c).astype(int)
    y_score_c = y_proba[:, c]

    fpr, tpr, _ = roc_curve(y_true_c, y_score_c)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"Class {c} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], linestyle="--")  # random baseline
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("One-vs-Rest ROC Curves")
plt.legend()
plt.tight_layout()
plt.savefig("/output/Omni_73k_Omni1399_ROC.pdf")
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.calibration import calibration_curve
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_regression
from sklearn.ensemble import RandomForestRegressor
import pandas as pd

bins = np.linspace(min(y_pred), max(y_pred), 20)
bin_ids = np.digitize(y_pred, bins)

bin_true = [y_test[bin_ids == i].mean() for i in range(1, len(bins))]
bin_pred = [y_pred[bin_ids == i].mean() for i in range(1, len(bins))]

plt.figure()
plt.plot(bin_pred, bin_true, marker="o")
plt.plot([min(y_pred), max(y_pred)], [min(y_pred), max(y_pred)], "--")
plt.xlabel("Predicted value")
plt.ylabel("Actual value")
plt.title("Regression Calibration Plot")
plt.savefig("/output/Omni Quant regression calibration plot.pdf")

plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.calibration import calibration_curve
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_regression
from sklearn.ensemble import RandomForestRegressor
import pandas as pd


bins = np.linspace(min(y_pred), max(y_pred), 20)
bin_ids = np.digitize(y_pred, bins)

bin_true = [y_test[bin_ids == i].mean() for i in range(1, len(bins))]
bin_pred = [y_pred[bin_ids == i].mean() for i in range(1, len(bins))]

plt.figure()
plt.plot(bin_pred, bin_true, marker="o")
plt.plot([min(y_pred), max(y_pred)], [min(y_pred), max(y_pred)], "--")
plt.xlabel("Predicted value")
plt.ylabel("Actual value")
plt.title("Regression Calibration Plot")
plt.savefig("/output/Genesis Quant regression calibration plot.pdf")

plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
